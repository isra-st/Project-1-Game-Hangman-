# %%
import os 

def welcome_player():
    name=input("Hey, what's your name? ").capitalize()
    print(f"\nHello and Welcome {name}!")
    print(f"\n{'*'*10} Let's Play Hangman {'*'*10}")
    name_user = name
    return name_user

import random
def picking_fille():
    """for acces list of word (ALL CAPS):
      http://www.mieliestronk.com/wordlist.html
      
    """ 
    print("Updating filles...")
    word_list = open('word_list.txt', 'r')
    return word_list

def random_valid_word(word_list):
    word_possible = word_list.readlines()
    for i in word_possible:
        if len(i) > 9:
            word_possible.remove(i)
    word_pc=random.choice(word_possible)
    return word_pc


def play_game(word_pc, name_user):
    word_to_guess = "-" *(len(word_pc)-1)
    rounds = 8    
    used_letter = set()
    used_word = set()
    win = False
    print(word_pc)
    print(len(word_pc))
    print(display_hangman(rounds))
    while win == False and rounds > 0:
        choice_user = input("Please try a letter or a word : ").upper()
        print(word_pc)
        print(len(word_pc))
        print(type(word_pc))
        print(len(choice_user))
        print(type(choice_user))
        if len(choice_user) == 1 and choice_user.isalpha():
            if choice_user in used_letter:
                print(f"You already try this letter : {choice_user}")
                rounds += 0
            elif choice_user not in word_pc:
                print(f"{choice_user} has no place in this word")
                used_letter.add(choice_user)
                rounds -= 1
            else:
                print(f"\nCool, {choice_user} is in the word")
                used_letter.add(choice_user)

                word_to_complete_list = list(word_to_guess)
                indices = [n for n, l in enumerate(word_pc) if l == choice_user]
                for index in indices:
                    word_to_complete_list[index] = choice_user
                word_to_guess = "".join(word_to_complete_list)
                if word_to_guess in word_pc:
                    win = True             
            
        elif len(choice_user) >= 2 and choice_user.isalpha():
            if len(choice_user) == len(word_pc)-1:
                if choice_user in used_word:
                    print(f"\nYou already try this word : {choice_user}")
                    print(f"""\nThese are the words already chosen :
                    {used_word}""")
                elif choice_user != word_pc:
                    print(f"\n{choice_user} is not the word. Sorry :(")
                    used_word.add(choice_user)
                    rounds -= 1
                else: 
                    print(f"\nUhuul! {choice_user} is the correct word!")
                    word_to_guess = choice_user  
                    win = True
            else:
                print(len(choice_user))
                print(f"\nWhat? {choice_user} has not even the same lenght")                   
        else:
            print(f"\nWhat are you doing? {choice_user} it's not even a possibility")
        print(display_hangman(rounds))
        print(word_to_guess)
            
    if win == True:
        print(f"{word_to_guess} is the right {word_pc}")
        print(f"\n{name_user} saved the hanging man! {escaped_man} ")
    else:
        print(f"""\n{name_user} just let this man die!
        The word to save him was {word_pc}""")   

escaped_man= """
                               O_/ < FREEDOOMMMM
                             _/|
                             __)\\
                             `  /_
                        
            """ 
                       

def display_hangman(rounds):
    stages = [  """
    
                   -------+
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |    ./ \\.
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     / \\
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     /
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |     \\|
                   |      |
                   |
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |      |
                   |      |
                   |
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |      |
                   |      
                   |
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |
                   |
                   |
                  ===
                   """,
                   """
                   
                   -------+
                   |      |
                   |      
                   |
                   |
                   |
                  ===
                   """
    ]


    return stages[rounds]

def re_play(hangman):
    re_play_it = 0
    while re_play_it == 0:
            re_play_it = (input(f"\nWould you like to re-play it?").upper())
            if re_play_it.isalpha():
                if re_play_it == ('YES') or ('Y'):
                    print(hangman())
                elif re_play_it == ('NO') or ('N'):
                    print(f"\n Well, in France we prefer to cut the heads off")
            else:
                    print(f"{re_play_it} is not a valid option. Please choose Yes or No")
                    re_play_it = ""       
    return try_again
            
def hangman(): 
        name_user = welcome_player()
        word_list = picking_fille()
        word_pc = random_valid_word(word_list)
        play_game(word_pc, name_user)
        try_again = re_play(hangman)

# %%
print(hangman())
# Out:
# Hey, what's your name? bruna
#
# Hello and Welcome Bruna!
#
# ********** Let's Play Hangman **********
# Updating filles...
# STONILY
#
# 8
#
#
#                    -------+
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                   ===
#
# Please try a letter or a word : s
# STONILY
#
# 8
# <class 'str'>
# 1
# <class 'str'>
#
# Cool, S is in the word
#
#
#                    -------+
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                   ===
#
# S------
# Please try a letter or a word : t
# STONILY
#
# 8
# <class 'str'>
# 1
# <class 'str'>
#
# Cool, T is in the word
#
#
#                    -------+
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                   ===
#
# ST-----
# Please try a letter or a word : o
# STONILY
#
# 8
# <class 'str'>
# 1
# <class 'str'>
#
# Cool, O is in the word
#
#
#                    -------+
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                   ===
#
# STO----
# Please try a letter or a word : n
# STONILY
#
# 8
# <class 'str'>
# 1
# <class 'str'>
#
# Cool, N is in the word
#
#
#                    -------+
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                   ===
#
# STON---
# Please try a letter or a word : l
# STONILY
#
# 8
# <class 'str'>
# 1
# <class 'str'>
#
# Cool, L is in the word
#
#
#                    -------+
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                   ===
#
# STON-L-
# Please try a letter or a word : i
# STONILY
#
# 8
# <class 'str'>
# 1
# <class 'str'>
#
# Cool, I is in the word
#
#
#                    -------+
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                   ===
#
# STONIL-
# Please try a letter or a word : y
# STONILY
#
# 8
# <class 'str'>
# 1
# <class 'str'>
#
# Cool, Y is in the word
#
#
#                    -------+
#                    |      |
#                    |
#                    |
#                    |
#                    |
#                   ===
#
# STONILY
# STONILY is the right STONILY
#
#
# Bruna saved the hanging man!
#                                O_/ < FREEDOOMMMM
#                              _/|
#                              __)\
#                              `  /_
#
#
#
# Would you like to re-play it?7
# 7 is not a valid option. Please choose Yes or No
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-54bf67e6f457> in <module>
# ----> 1 print(hangman())
#
# <ipython-input-1-da7ee476df06> in hangman()
#     209         word_pc = random_valid_word(word_list)
#     210         play_game(word_pc, name_user)
# --> 211         try_again = re_play(hangman)
#     212
#     213
#
# <ipython-input-1-da7ee476df06> in re_play(hangman)
#     202                     print(f"{re_play_it} is not a valid option. Please choose Yes or No")
#     203                     re_play_it = ""
# --> 204     return try_again
#     205
#     206 def hangman():
#
# NameError: name 'try_again' is not defined

# %%
import random
word_possible = open('word_list.txt', 'r')
words= word_possible.readlines()
for i in words:
    if len(i) > 8:
        words.remove(i)

print(words[1])
print(len(words[1]))
print(type(words))
word_pc=random.choice(words)

print(word_pc)
print(len(word_pc))
print(type(word_pc))
