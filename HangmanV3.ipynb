# %%
secret_word = []
def random():
    word_list = []
    darty_list = []
    word_possible = []
    import os
    os.getcwd()
    os.chdir('D:\\Repositories\\Project-1-Game-Hangman-\\list')
    with open("list.txt", "r") as f:
        lines = f.readlines()
        darty_list = [(line.split()[0].split(",")) for line in lines]
    for word in darty_list:
        word_list = word_list + word
    import random
    for i in word_list:
        if len(i) < 8 and len(i) > 3:
            word_possible.append(i)
            secret_word=random.choice(word_possible).upper()
    return secret_word

# %%
secret_word = random()
empty_list = "_" * len(secret_word)
flag = False
all_letters = []
all_words = []
fails = 7
value = ''
secret_list = []
secret_word_list = []

# %%
def welcome_player():
    name=input("Hey, what's your name? ").capitalize()
    print(f"\nHello and Welcome {name}!")
    print(f"\n{'*'*10} Let's Play Hangman {'*'*10}")
    name_user = name
    return name_user

# %%
escaped_man= """
                               O_/ < FREEDOOMMMM
                             _/|
                             __)\\
                             `  /_
                        
            """ 
                       

def display_hangman(rounds):
    stages = [  """
    
                   -------+
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |    ./ \\.
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     / \\
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |     /
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |     \\|/
                   |      |
                   |
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |     \\|
                   |      |
                   |
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |      |
                   |      |
                   |
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |      |
                   |      
                   |
                  ===
                   """,
                   """
                   -------+
                   |      |
                   |      O
                   |
                   |
                   |
                  ===
                   """,
                   """
                   
                   -------+
                   |      |
                   |      
                   |
                   |
                   |
                  ===
                   """
    ]


    return stages[rounds]

# %%
def pictures(fails):
    
    from IPython.display import display, Image
    from IPython.display import Image
    from IPython.core.display import HTML
    fail6 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\1st.png")
    fail5 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\2rd.png")
    fail4 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\3rd.png")
    fail3 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\4th.png")
    fail2 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\5th.png")
    fail1 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\6th.png")
    fail0 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\7th.png")
    
    if fails == 7:
        return fail6
    elif fails == 6:
        return fail5
    elif fails == 5:
        return fail4
    elif fails == 4:
        return fail3
    elif fails == 3:
        return fail2
    elif fails == 2:
        return fail1
    elif fails == 1:
        return fail0
    else:
        pass
    
""""
    fail6 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\1st.png")
    fail5 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\2rd.png")
    fail4 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\3rd.png")
    fail3 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\4th.png")
    fail2 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\5th.png")
    fail1 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\6th.png")
    fail0 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\7th.png")
"""
# Out:
# '"\n    fail6 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\1st.png")\n    fail5 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\2rd.png")\n    fail4 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\3rd.png")\n    fail3 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\4th.png")\n    fail2 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\5th.png")\n    fail1 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\6th.png")\n    fail0 = Image(url= "C:\\Users\\israe\\OneDrive\\Data Analytics\\Projects\\Hangman - week1\\Pictures\\7th.png")\n'

# %%
def rounds(value):
    from IPython.display import display, Image
    empty_list = "_" * len(secret_word)
    flag = False
    all_letters = []
    all_words = []
    fails = 7
    value = ''
    secret_list = []
    secret_word_list = []
    pictures(fails)
    print('\Let\'s play HANGMAN')
    print('The word will have a lenght of:', len(secret_word),'lettes', empty_list)
    while not flag and (fails > 0):    
        print('You can add the WORD or the letter in the below field')
        value = input('Add your letter, below\n').upper()
        if len(value) == 1 & value.isalpha():
            if value in all_letters:
                print('You have already used this word, do you wanna die?', all_letters)
            elif len(value) > 1: 
                print('If you don\'t want to add a word you can only add ONE letter')
            elif value not in secret_word:
                print(value,'is WRONG, this letter is not in the word')
                fails = fails-1
                pictures(fails)
                print('you still have', fails, 'to live')
                all_letters.append(value)
                print(empty_list)
            else: 
                print('Well done you can still live another day, next letter please:')
                secret_list.append(value)
                secret_word_list = list(empty_list)
                indices = []
                for i,j in enumerate(secret_word):
                    if j in value:
                        indices.append(i)
                for i in indices:
                    secret_word_list[i] = value
                empty_list = "".join(secret_word_list)
                if "_" not in empty_list:
                    flag = True
                    all_letters.append(value)
                print(empty_list)
                print('Here the list of letters added', all_letters)
        elif len(value) > 3 and value.isalpha():
            if value in all_words:
                print('What a mind\! this word was already used')
            elif value != secret_word:
                print('Nice try, BUT this word is not the correct one')
                fails = fails-1
                pictures(fails)
                print('you still have', fails, 'to live')
                all_words.append(value) 
            else: 
                flag = True 
                empty_list = secret_word
        else: 
            print('The error hanling is secure, you failed breaking the game')
    if flag:
        print('You will live one day more! Lucky you!')
    else:
        print("You die")

# %%
def play():
    secret_word = random()
    print(secret_word)
    pictures(fails)
    rounds(value)

# %%
def re_play(hangman):
    try_again = False
    while not try_again:
            re_play_it = (input(f"\nWould you like to re-play it?").upper())
            if re_play_it.isalpha():
                if re_play_it == 'YES' or re_play_it == 'Y':
                    try_again = True
                    print(hangman())
                elif re_play_it == 'NO' or re_play_it == 'N':
                    print(f"\nWell, in France do we prefer to cut the heads off")
                    break
            else:
                    print(f"{re_play_it} is not a valid option. Please choose Yes or No")
                    try_again = False

# %%
def hangman(): 
        name_user = welcome_player()
        word_list = picking_file()
        word_pc = random_valid_word(word_list)
        play_game(word_pc, name_user)
        re_play(hangman)

# %%
play()
# Out:
# LINGO
# \Let's play HANGMAN
# The word will have a lenght of: 6 lettes ______
# You can add the WORD or the letter in the below field
# Add your letter, below
# LINGO
# Nice try, BUT this word is not the correct one
# you still have 6 to live
# You can add the WORD or the letter in the below field
# Add your letter, below
# a
# Well done you can still live another day, next letter please:
# __A___
# Here the list of letters added []
# You can add the WORD or the letter in the below field
# Add your letter, below
# s
# Well done you can still live another day, next letter please:
# __AS__
# Here the list of letters added []
# You can add the WORD or the letter in the below field
# Add your letter, below
# d
# D is WRONG, this letter is not in the word
# you still have 5 to live
# __AS__
# You can add the WORD or the letter in the below field
# Add your letter, below
# f
# Well done you can still live another day, next letter please:
# F_AS__
# Here the list of letters added ['D']
# ...
